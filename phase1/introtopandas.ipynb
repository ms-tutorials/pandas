# %% [markdown]
# # Introduction to Pandas
# Pandas is a powerful library for data manipulation and analysis. This notebook introduces its core features and functionalities.

# %% [markdown]
# ## Pandas
#
# Pandas is an open-source library built on top of Python that provides high-performance, easy-to-use data structures and data analysis tools. It’s perfect for handling structured data (like tables), and it integrates well with other Python libraries like NumPy, Matplotlib, and Scikit-learn.

# %%
! pip install pandas numpy matplotlib seaborn

# %% [markdown]
# ```python
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie'],
#     'Age': [25, 30, 35],
#     'City': ['New York', 'Los Angeles', 'Chicago']
# }
#
# df = pd.DataFrame(data)
# ```

# %% [markdown]
# ### Importing Pandas

# %%
import pandas as pd
# import numpy as np

# %% [markdown]
# ### Reading Data in Pandas
# Pandas provides functions like `read_csv` to load data from various file formats into a DataFrame.

# %%
df = pd.read_csv("../data/WineQT.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# ### Accessing a Single Column

# %%
df["sulphates"]
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
#         ...
# 1138    0.75
# 1139    0.82
# 1140    0.58
# 1141    0.76
# 1142    0.71
# Name: sulphates, Length: 1143, dtype: float64

# %%
df.sulphates
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
#         ...
# 1138    0.75
# 1139    0.82
# 1140    0.58
# 1141    0.76
# 1142    0.71
# Name: sulphates, Length: 1143, dtype: float64

# %% [markdown]
# ### Accessing a Single Row

# %%
df.iloc[2]
# Out:
# fixed acidity            7.800
# volatile acidity         0.760
# citric acid              0.040
# residual sugar           2.300
# chlorides                0.092
# free sulfur dioxide     15.000
# total sulfur dioxide    54.000
# density                  0.997
# pH                       3.260
# sulphates                0.650
# alcohol                  9.800
# quality                  5.000
# Id                       2.000
# Name: 2, dtype: float64

# %% [markdown]
# ### Filtering Data
# Filtering allows us to extract rows that meet specific conditions, making it easier to focus on relevant data.

# %%
df[df["sulphates"] <= 0.5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 45              7.2             0.725         0.05            4.65      0.086
# 46              7.2             0.725         0.05            4.65      0.086
# 49              7.7             0.690         0.22            1.90      0.084
# ...             ...               ...          ...             ...        ...
# 1012            7.8             0.530         0.01            1.60      0.077
# 1025            7.0             0.590         0.00            1.70      0.052
# 1027            6.9             0.580         0.20            1.75      0.058
# 1047           10.0             0.690         0.11            1.40      0.084
# 1131            6.1             0.715         0.10            2.60      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 45                    4.0                  11.0  0.99620  3.41       0.39
# 46                    4.0                  11.0  0.99620  3.41       0.39
# 49                   18.0                  94.0  0.99610  3.31       0.48
# ...                   ...                   ...      ...   ...        ...
# 1012                  3.0                  19.0  0.99500  3.16       0.46
# 1025                  3.0                   8.0  0.99600  3.41       0.47
# 1027                  8.0                  22.0  0.99322  3.38       0.49
# 1047                  8.0                  24.0  0.99578  2.88       0.47
# 1131                 13.0                  27.0  0.99362  3.57       0.50
#
#       alcohol  quality    Id
# 6         9.4        5     6
# 7        10.0        7     7
# 45       10.9        5    64
# 46       10.9        5    65
# 49        9.5        5    72
# ...       ...      ...   ...
# 1012      9.8        5  1420
# 1025     10.3        5  1438
# 1027     11.7        5  1443
# 1047      9.7        5  1470
# 1131     11.9        5  1582
#
# [122 rows x 13 columns]

# %% [markdown]
# ### Filtering with Multiple Conditions

# %%
df[(df["sulphates"] <= 0.5 ) & (df["alcohol"] == 9)]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 118            7.3              0.55         0.03             1.6      0.072
# 532            8.2              0.34         0.38             2.5      0.080
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 118                 17.0                  42.0   0.9956  3.37       0.48
# 532                 12.0                  57.0   0.9978  3.30       0.47
#
#      alcohol  quality   Id
# 118      9.0        4  167
# 532      9.0        6  746

# %% [markdown]
# ### Adding and Modifying Data in Pandas

# %%
df["Total Acidity"] = (df["fixed acidity"] + df["volatile acidity"])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id  Total Acidity
# 0      9.4        5   0           8.10
# 1      9.8        5   1           8.68
# 2      9.8        5   2           8.56
# 3      9.8        6   3          11.48
# 4      9.4        5   4           8.10

# %% [markdown]
# ### Grouping and Aggregating Data
# Grouping and aggregation are powerful tools for summarizing data based on specific criteria.

# %%
df.groupby("Total Acidity")["pH"].count()
# Out:
# Total Acidity
# 5.120     1
# 5.320     1
# 5.380     1
# 5.400     1
# 5.420     1
#          ..
# 15.210    2
# 16.145    1
# 16.245    1
# 16.260    1
# 16.285    1
# Name: pH, Length: 666, dtype: int64

# %% [markdown]
# ### Sorting Data

# %%
df.sort_values("fixed acidity", ascending=False)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 462           15.9             0.360         0.65             7.5      0.096
# 311           15.6             0.685         0.76             3.7      0.100
# 399           15.6             0.645         0.49             4.2      0.095
# 397           15.5             0.645         0.49             4.2      0.095
# 171           15.0             0.210         0.44             2.2      0.075
# ..             ...               ...          ...             ...        ...
# 419            5.0             0.420         0.24             2.0      0.060
# 787            5.0             0.400         0.50             4.3      0.046
# 898            5.0             0.380         0.01             1.6      0.048
# 589            4.9             0.420         0.00             2.1      0.048
# 32             4.6             0.520         0.15             2.1      0.054
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 462                 22.0                  71.0  0.99760  2.98       0.84
# 311                  6.0                  43.0  1.00320  2.95       0.68
# 399                 10.0                  23.0  1.00315  2.92       0.74
# 397                 10.0                  23.0  1.00315  2.92       0.74
# 171                 10.0                  24.0  1.00005  3.07       0.84
# ..                   ...                   ...      ...   ...        ...
# 419                 19.0                  50.0  0.99170  3.72       0.74
# 787                 29.0                  80.0  0.99020  3.49       0.66
# 898                 26.0                  60.0  0.99084  3.70       0.75
# 589                 16.0                  42.0  0.99154  3.71       0.74
# 32                   8.0                  65.0  0.99340  3.90       0.56
#
#      alcohol  quality    Id  Total Acidity
# 462     14.9        5   652         16.260
# 311     11.2        7   442         16.285
# 399     11.1        5   557         16.245
# 397     11.1        5   554         16.145
# 171      9.2        7   244         15.210
# ..       ...      ...   ...            ...
# 419     14.0        8   588          5.420
# 787     13.6        6  1114          5.400
# 898     14.0        6  1270          5.380
# 589     14.0        7   821          5.320
# 32      13.1        4    45          5.120
#
# [1143 rows x 14 columns]

# %% [markdown]
# ### Dataframe

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago'],
    'town':["Githurai","ruiru","thika"]
}

data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'City': ['New York', 'Los Angeles', 'Chicago'],
#  'town': ['Githurai', 'ruiru', 'thika']}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City      town
# 0    Alice   25     New York  Githurai
# 1      Bob   30  Los Angeles     ruiru
# 2  Charlie   35      Chicago     thika

# %% [markdown]
# ### Series

# %%
df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df.Age
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df["Age"].mean()
# Out:
# np.float64(30.0)

# %% [markdown]
# #### Multiple Cols

# %%
df[["Name","Age"]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ### Exporting Data

# %%
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 118            7.3              0.55         0.03             1.6      0.072
# 532            8.2              0.34         0.38             2.5      0.080
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 118                 17.0                  42.0   0.9956  3.37       0.48
# 532                 12.0                  57.0   0.9978  3.30       0.47
#
#      alcohol  quality   Id
# 118      9.0        4  167
# 532      9.0        6  746

# %%
df.to_csv("../data/wines.csv")

# %% [markdown]
# ### Reading a Dataset From File

# %%
df_wine = pd.read_csv("../data/WineQT.csv")
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %% [markdown]
# ### Basic DataFrame Operations
#
#     Inspecting Data
#         .head() - Returns the first 5 rows.
#         .tail() - Returns the last 5 rows.
#         .info() - Provides summary of DataFrame.
#         .describe() - Returns descriptive statistics.

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df_wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %% [markdown]
# #### Accessing Data
#
#     Access a column:

# %%
df_wine["alcohol"]
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1138    11.0
# 1139     9.5
# 1140    10.5
# 1141    11.2
# 1142    10.2
# Name: alcohol, Length: 1143, dtype: float64

# %% [markdown]
# #### Accessing Data with .loc[] and .iloc[] in Pandas

# %% [markdown]
# ##### loc[] — Label-Based Indexing
#
# The .loc[] method is used for label-based indexing. This means you access rows and columns by their labels (names), which could be column names or the index of the DataFrame.

# %% [markdown]
# ```python
# df.loc[row_label, column_label]
# ```

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
#single row
df_wine.loc[2]
# Out:
# fixed acidity            7.800
# volatile acidity         0.760
# citric acid              0.040
# residual sugar           2.300
# chlorides                0.092
# free sulfur dioxide     15.000
# total sulfur dioxide    54.000
# density                  0.997
# pH                       3.260
# sulphates                0.650
# alcohol                  9.800
# quality                  5.000
# Id                       2.000
# Name: 2, dtype: float64

# %%
# multiple rows [start:Stop]
df_wine.loc[2:3, "alcohol"]
# Out:
# 2    9.8
# 3    9.8
# Name: alcohol, dtype: float64

# %%
# multiple rows with specific columns
df_wine.loc[2:3,["alcohol","pH"]]
# Out:
#    alcohol    pH
# 2      9.8  3.26
# 3      9.8  3.16

# %% [markdown]
# ### .iloc[] — Integer-Position Based Indexing
#
# The .iloc[] method is used for integer-location based indexing. This means you access rows and columns by their integer position (indexing starts from 0).
# Basic Syntax for .iloc[]:
#
# ```python
# df.iloc[row_index, column_index]
# ```
#
#     row_index: The integer position of the row (starting from 0).
#     column_index: The integer position of the column (starting from 0).

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
df_wine.iloc[0,[7,9]]
# Out:
# density      0.9978
# sulphates    0.5600
# Name: 0, dtype: float64

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Salary": [50000, 6000, 70000]
}

df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %% [markdown]
# ### Handling Missing Data

# %%
data = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Salary": [50000, None, 70000]
})

df = data

df
# Out:
#       Name  Age   Salary
# 0    Alice   25  50000.0
# 1      Bob   30      NaN
# 2  Charlie   35  70000.0

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

df
# Out:
#       Name  Age   Salary
# 0    Alice   25  50000.0
# 1      Bob   30  60000.0
# 2  Charlie   35  70000.0

# %% [markdown]
# ## Data Visualization: Telling Stories with Data

# %% [markdown]
# #### Matplotlib

# %%
import matplotlib.pyplot as plt

years = [2018, 2019, 2020, 2021]
sales = [100, 200, 300, 400]

plt.plot(years, sales, marker='o')
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Yearly Sales Growth")
plt.show()

# %% [markdown]
# ### Seaborn: Beautiful and Easy Plots

# %%
import seaborn as sns

sns.barplot(x=["A", "B", "C"], y=[10, 20, 30])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)
data = np.random.normal(0, 1, 100000)

mean = np.mean(data)
std = np.std(data)

plt.hist(data, bins=30, density=True, alpha=0.7)

plt.axvline(mean, color='r', linestyle='dashed', label='Mean')
plt.axvline(mean - 3*std, color='m', linestyle='dashed', label='-3 STD')
plt.axvline(mean + 3*std, color='m', linestyle='dashed', label='+3 STD')

plt.title('Outliers Using Standard Deviation')
plt.legend()
plt.show()
